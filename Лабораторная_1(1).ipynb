# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !wget https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv .
# Out:
# --2024-09-30 18:00:14--  https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv
# Resolving web.stanford.edu (web.stanford.edu)... 171.67.215.200, 2607:f6d0:0:925a::ab43:d7c8
# Connecting to web.stanford.edu (web.stanford.edu)|171.67.215.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 44225 (43K) [text/csv]
# Saving to: ‘titanic.csv.2’
#
# titanic.csv.2       100%[===================>]  43.19K  --.-KB/s    in 0.06s
#
# 2024-09-30 18:00:14 (757 KB/s) - ‘titanic.csv.2’ saved [44225/44225]
#
# --2024-09-30 18:00:14--  http://./
# Resolving . (.)... failed: No address associated with hostname.
# wget: unable to resolve host address ‘.’
# FINISHED --2024-09-30 18:00:14--
# Total wall clock time: 0.3s
# Downloaded: 1 files, 43K in 0.06s (757 KB/s)

# %% [markdown]
# ## Задание 1
# Прочитайте файл в датафрейм, так, чтобы появились корректные колонки без каких-либо дополнительных действий, и отобразите первые 5 строчек

# %%
# Ваш код
data = pd.read_csv("https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv")

data.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %% [markdown]
# ## Задание 2
# Вывести имена всех выживших детей и их количество (у детей возраст < 18)

# %%
# Ваш код
# Имена всех выживших детей

data[(data.Age < 18) & (data.Survived == 1)].Name
# Out:
# 9           Mrs. Nicholas (Adele Achem) Nasser
# 10              Miss. Marguerite Rut Sandstrom
# 22                          Miss. Anna McGowan
# 39                  Miss. Jamila Nicola-Yarred
# 42     Miss. Simonne Marie Anne Andree Laroche
#                         ...
# 826     Mrs. Antoni (Selini Alexander) Yasbeck
# 827             Master. George Sibley Richards
# 849                   Miss. Mary Conover Lines
# 865             Master. Harold Theodor Johnson
# 871                   Miss. Adele Kiamie Najib
# Name: Name, Length: 65, dtype: object

# %%
# Ваш код
# Количество выживших детей

print("Количество выживших детей")
data[(data.Age < 18) & (data.Survived == 1)].shape[0]
# Out:
# Количество выживших детей
# 65

# %% [markdown]
# ## Задание 3
# Сделайте индексом колонку Name

# %%
# Ваш код
data.set_index("Name")
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Mr. Owen Harris Braund                                     0       3    male
# Mrs. John Bradley (Florence Briggs Thayer) Cumings         1       1  female
# Miss. Laina Heikkinen                                      1       3  female
# Mrs. Jacques Heath (Lily May Peel) Futrelle                1       1  female
# Mr. William Henry Allen                                    0       3    male
# ...                                                      ...     ...     ...
# Rev. Juozas Montvila                                       0       2    male
# Miss. Margaret Edith Graham                                1       1  female
# Miss. Catherine Helen Johnston                             0       3  female
# Mr. Karl Howell Behr                                       1       1    male
# 211  22.0         0                              Mr. John Henry Perkin
# 221  51.0         0                             Mr. George Henry Green
# 229  35.0         1        Mrs. Henry Birkhardt (Irene Wallach) Harris
# 238  33.0         0                              Mr. George Henry Hunt
# 262  21.0         0                                  Miss. Delia Henry
# 269  25.0         1                        Mr. William Henry Tornquist
# 332  42.0         1  Mrs. Henry William (Clara Heinsheimer) Frauenthal
# 345  34.0         1           Mrs. Thomas Henry (Mary E Finck) Davison
# 383  18.0         0                           Mr. Charles Henry Davies
# 409  27.0         0                                     Mr. Henry Hart
# 473  34.0         0                             Mr. Peter Henry Renouf
# 479  50.0         0                            Mr. Richard Henry Rouse
# 505  28.0         0                            Mr. Henry Margido Olsen
# 591  37.0         0                             Mr. John Henry Chapman
# 620  21.0         0                         Mr. Henry Damsgaard Hansen
# 627  80.0         1                Mr. Algernon Henry Wilson Barkworth
# 630  30.0         0                       Mr. William Henry Marsh Parr
# 642  48.0         1                           Mr. Henry Sleeper Harper
# 657  50.0         1                       Dr. Henry William Frauenthal
# 669  70.0         0                         Mr. Henry Michael Mitchell
# 692  52.0         0                          Mr. Charles Henry Chapman
# 702  39.0         0                            Mr. Henry Samuel Morley
# 718  34.0         0                        Mr. William Henry Gillespie
# 719  50.0         0                             Mr. Henry Price Hodges
# 722  30.0         1         Mrs. Peter Henry (Lillian Jefferys) Renouf
# 880  25.0         0                              Mr. Henry Jr Sutehall

# %% [markdown]
# ## Задание 5
# Посчитайте среднюю выживаемость в зависимости от приставки в имени.
#
# *Подсказка: приставка -- первое слово, или то слово, которое обозначается через точку (см результат для Henry). Воспользуйтесь groupby и строковыми методами работы .str*

# %%
# Ваш код
data.groupby(data.index.str.split(".").str[0])["Survived"].mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-066a513c8186> in <cell line: 2>()
#       1 # Ваш код
# ----> 2 data.groupby(data.index.str.split(".").str[0])["Survived"].mean()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
#     225         # Replace the property with the accessor object. Inspired by:
#     226         # https://www.pydanny.com/cached-property.html
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/strings/accessor.py in __init__(self, data)
#     188         from pandas.core.arrays.string_ import StringDtype
#     189
# --> 190         self._inferred_dtype = self._validate(data)
#     191         self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     192         self._is_string = isinstance(data.dtype, StringDtype)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/strings/accessor.py in _validate(data)
#     242
#     243         if inferred_dtype not in allowed_types:
# --> 244             raise AttributeError("Can only use .str accessor with string values!")
#     245         return inferred_dtype
#     246
#
# AttributeError: Can only use .str accessor with string values!

# %% [markdown]
# ## Задание 6
# Постройте гистограмму по признаку Survived

# %%
# Ваш код
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv")

plt.hist(data.Survived)

plt.title("Гистограмма по признаку Survived")
plt.xticks([0, 1])  # оставляем целые числа в оси абсцисс
# Out:
# ([<matplotlib.axis.XTick at 0x7c55f9a23820>,
#   <matplotlib.axis.XTick at 0x7c55f9a237f0>],
#  [Text(0, 0, '0'), Text(1, 0, '1')])

# %% [markdown]
# ## Задание 7
# С помощью pairplot постройте попарные графики с раскраской по полю Survived.

# %%
# Ваш код
data = pd.read_csv("https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv")

sns.pairplot(data, hue = "Survived")
plt.show()

# %% [markdown]
# ## Задание 8
# Точки накладываются друг на друга, не очень понятно что происходит, найдите способ отобразить точки с параметром прозрачности и снова постройте pairplot.
#
# *Подсказка: гугл.*

# %%
# Ваш код
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv("https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv")

sns.pairplot(data, hue = "Survived", plot_kws = {'alpha': 0.5})
plt.show()

# %% [markdown]
# ## Задание 9
# Теперь мы лучше видим концентрацию точек, давайте посмотрим более детально на разрез возраст/класс/пол пассажира.
#
# Сделайте FacetGrid в разбиении по Pclass.
#
# Вы можете найти полезным вот [этот материал](https://nagornyy.me/it/vizualizatsiia-dannykh-v-seaborn/#facet-grid)

# %%
# Ваш код
import pandas as pd
import seaborn as sns

data = pd.read_csv("https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv")

grid = sns.FacetGrid(data, col = "Pclass", row = "Sex", height = 4, aspect = 1.2)
grid.map_dataframe(sns.histplot, x = "Age", kde = False, bins = 20, color='c', alpha = 0.6)

plt.show()

# %% [markdown]
# ## Задание 10
# Постройте еще какой-нибудь интересный по вашему мнению график, приведенный в материале выше. Объясните почему вы построили именно его.

# %%
# Ваш код
import pandas as pd
import seaborn as sns

data = pd.read_csv("https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv")

grid = sns.FacetGrid(data, col = "Survived", row = "Sex", height = 4, aspect = 1.2)
grid.map_dataframe(sns.histplot, x = "Age", kde = False, bins = 20, color='c', alpha = 0.6)

plt.show()

# %% [markdown]
# ## Задание 11
# Постройте сводную таблицу (pivot_table), отражающую долю выживших, класс пассажира и его пол, используя groupby + unstack

# %%
# Ваш код
import pandas as pd
import seaborn as sns

data = pd.read_csv("https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv")

pivot_table = data.groupby(['Pclass', 'Sex'])['Survived'].mean().unstack()
print(pivot_table)
# Out:
# Sex       female      male
# Pclass
# 1       0.968085  0.368852
# 2       0.921053  0.157407
# 3       0.500000  0.137026

# %% [markdown]
# ## Задание 12
# Постройте сводную таблицу (pivot_table), отражающую долю выживших, класс пассажира и его пол, используя метод pivot_table

# %%
# Ваш код
import pandas as pd
import seaborn as sns

data = pd.read_csv("https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv")

pivot_table = pd.pivot_table(data, values = 'Survived', index = 'Pclass', columns = 'Sex', aggfunc = 'mean')
print(pivot_table)
# Out:
# Sex       female      male
# Pclass
# 1       0.968085  0.368852
# 2       0.921053  0.157407
# 3       0.500000  0.137026

# %% [markdown]
# ## Задание 13
# Попробуйте найти еще какой-нибудь фактор выживаемости с помощью доступных вам сейчас методов.
#
# Т.е, используя выборки, аггрегацию, графики

# %%
# Ваш код
